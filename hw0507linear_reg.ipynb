# %%
import numpy as np
import pandas as pd
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # exercise

# %%
'''1'''
x_value1 = np.linspace(-15,35,20)

# x + y = 12 -> y = -x + 12
y_value1 = -1 * x_value1 + 12
# x - y = 4 -> y = x - 4
y_value2 = x_value1 - 4 

plt.axhline(0, color='black', linewidth=0.8, linestyle='--')
plt.axvline(0, color='black', linewidth=0.8, linestyle='--')
plt.plot(x_value1, y_value1, color='blue', label='y = -x + 12')
plt.plot(x_value1, y_value2, color='red', label='y = x - 4')

plt.scatter(x_solution, y_solution, color="blue", zorder=5)
plt.annotate(f"({x_solution},{y_solution})",(x_solution, y_solution),xytext=(x_solution -1,y_solution+2), fontsize=10, color='green')

plt.xlim(-10, 20)
plt.ylim(-20, 20)

plt.title('Junction')
plt.grid()
plt.legend(loc='upper right')

# %%
'''2'''
from sympy import symbols, Eq, solve
# y = -x + 12
# y = x - 4
x = symbols('x')
eq1 = -x + 12
eq2 = x - 4
solution = solve(Eq(eq1, eq2), x)
print(solution)
print(type(solution)) # it comes out as a list

x_solution = float(solution[0]) # convert the solution to float
y_solution = x_solution - 4
print(y_solution)
# Out:
# [8]
# <class 'list'>
# 4.0

# %%
'''3'''
Y = np.array([2, 4, 8, 20])
Y_pred = np.array([2, 5, 10, 25])
mse = ((2 - 2) ** 2 + (4 - 5) ** 2 + (8 - 10) ** 2 + (20 - 25) ** 2) / 4
print('mse=',mse)
# Out:
# mse= 7.5

# %% [markdown]
# # learning

# %%
y_values1 = -1 * x_values + 5
y_values2 = 2 * x_values - 1

plt.axhline(0, color="black", linewidth=0.8, linestyle="--")
plt.axvline(0, color="black", linewidth=0.8, linestyle="--")
plt.plot(x_values, y_values1, color="green", label="y = -x + 5")
plt.plot(x_values, y_values2, color="red", label="y = 2x - 1")

x_junc = 2
y_junc = 3
plt.scatter(x_junc, y_junc, color="blue", zorder=5)
plt.annotate(
    f"({x_junc}, {y_junc})",
    (x_junc, y_junc),
    xytext=(x_junc - 1, y_junc + 3),
    fontsize=10,
    color="blue"
)

plt.title("Junction")
plt.xlim(-10, 20)
plt.ylim(-20, 20)
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.legend()
plt.show()
# Out:
#   Cell In[56], line 18
#     )
#     ^
# SyntaxError: positional argument follows keyword argument

# %%
def linear_function(x):
    y = 0.8 * x - 2
    return y

x_values = np.linspace(-15, 35, 20)
y_values = linear_function(x_values)

plt.axhline(0, color="black", linewidth=0.8, linestyle="--")
plt.axvline(0, color="black", linewidth=0.8, linestyle="--")
plt.plot(x_values, y_values, color="green")
plt.title("y = 0.8x - 2")
plt.xlim(-10, 20)
plt.ylim(-20, 20)
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.show()

# %%
from sympy import symbols, Eq, solve

x = symbols("x")
eq1 = -x + 5
eq2 = 2 * x - 1

solution = solve(Eq(eq1, eq2), x)
solution
# Out:
# [2]

# %%
X = np.array([1, 2, 3, 4])  # Features
Y = np.array([1, 2, 3, 4])  # Labels

"""
  X   Y
  1   1
  2   2
  3   3
  4   4

  7   ?
  12  ?
"""

plt.scatter(X, Y, zorder=5, s=100)

# %%
a = 1
b = 1
distance_sqr_arr = []

for i in range(len(X)):
    point_y_val = Y[i]
    point_on_line_y = a * X[i] + b
    distance = point_y_val - point_on_line_y
    distance_sqr = distance ** 2
    distance_sqr_arr.append(distance_sqr)

mse_result = np.array(distance_sqr_arr).mean()
mse_result
# Out:
# np.float64(1.0)

# %%
mse = ((Y - (a * X + b)) ** 2).mean()

# %%
ab = []
mse_arr = []

for a in np.arange(-5, +5, 1):
    for b in np.arange(-5, +5, 1):
        ab.append((a, b))
        mse = ((Y - (a * X + b)) ** 2).mean()
        mse_arr.append(mse)

mse_np = np.array(mse_arr)
print("lowest mse", mse_np.min())
print("index lowest = ", mse_np.argmin())
print("a =", ab[mse_np.argmin()][0], "b =", ab[mse_np.argmin()][1])

a, b = ab[mse_np.argmin()]

plt.plot(
    np.arange(X[0] - 1, X[len(X) - 1] + 1),
    a * np.arange(0, 4 + 1) + b,
    color="red"
)
plt.title("Linear Regression BF")
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.show()
# Out:
# lowest mse 0.0
# index lowest =  65
# a = 1 b = 0
